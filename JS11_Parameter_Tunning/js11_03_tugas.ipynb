# %% [markdown]
# # Tugas
#
#  1. Menggunakan data (WBC) dan alogirtma yang sama (DT) pada jobsheet js11_02, silahkan implemnetasikan ulang teknik *exhausive search* dengan menggunakan ***random search***. Scikit-learn sudah menyediakan fungsi ini.
#  2. Menggunakan data yang sama, lakukan tunning dengan menggunakan algoritma SVM. Hyperparamter yang akan ditunning adalah,
#     - kernel (linier, polinomial, rbf)
#     - degree (akan berdampak jika polinomial)
#     - koefisien C (regularization)

# %%
# LOAD ATAU PEMBERSIHAN DATA
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('data/wbc.csv')

# slice kolom terakhir --> Unnamed column
df = df.iloc[:,:-1]

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
# SELEKSI FITUR
X = df.iloc[:, 2:]
y = df['diagnosis']

X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
from sklearn.model_selection import RepeatedKFold

# repated k-fold
cv = RepeatedKFold(n_splits=4, n_repeats=3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

dt = DecisionTreeClassifier()
params = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': list(range(5,11))
}

#berdasarkan nilai repeated k-fold inisialisasikan dan hyperparameter
randoms = RandomizedSearchCV(dt, param_distributions=params, cv=cv, n_jobs=-1)

# Fit / latih berdasarkan grid
# %timeit merupakan magic command didalam ipython notebook
# yang dapat kita gunakan untuk menghitung waktu komputasi
# cara ini cukup efektif untuk melakukan evaluasi suatu algoritma atau prosedur
# %timeit random.fit(X, y)

# Evaluasi dengan score
score = grid.score(X,y)

print(f'Hasil evaluasi: {score}')
print(f'Konfigurasi hyperparameter: {randoms.best_params_}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Semester 5\Pembelajaran Mesin\jobsheets\JS11_Parameter_Tunning\js11_03_tugas.ipynb Cell 5 in <cell line: 18>()
#      <a href='vscode-notebook-cell:/d%3A/Semester%205/Pembelajaran%20Mesin/jobsheets/JS11_Parameter_Tunning/js11_03_tugas.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> randoms = RandomizedSearchCV(dt, param_distributions=params, cv=cv, n_jobs=-1)
#      <a href='vscode-notebook-cell:/d%3A/Semester%205/Pembelajaran%20Mesin/jobsheets/JS11_Parameter_Tunning/js11_03_tugas.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a> # Fit / latih berdasarkan grid
#      <a href='vscode-notebook-cell:/d%3A/Semester%205/Pembelajaran%20Mesin/jobsheets/JS11_Parameter_Tunning/js11_03_tugas.ipynb#W4sZmlsZQ%3D%3D?line=14'>15</a> # %timeit merupakan magic command didalam ipython notebook
#      <a href='vscode-notebook-cell:/d%3A/Semester%205/Pembelajaran%20Mesin/jobsheets/JS11_Parameter_Tunning/js11_03_tugas.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a> # yang dapat kita gunakan untuk menghitung waktu komputasi
#      <a href='vscode-notebook-cell:/d%3A/Semester%205/Pembelajaran%20Mesin/jobsheets/JS11_Parameter_Tunning/js11_03_tugas.ipynb#W4sZmlsZQ%3D%3D?line=16'>17</a> # cara ini cukup efektif untuk melakukan evaluasi suatu algoritma atau prosedur
# ---> <a href='vscode-notebook-cell:/d%3A/Semester%205/Pembelajaran%20Mesin/jobsheets/JS11_Parameter_Tunning/js11_03_tugas.ipynb#W4sZmlsZQ%3D%3D?line=17'>18</a> get_ipython().run_line_magic('timeit', 'random.fit(X, y)')
#      <a href='vscode-notebook-cell:/d%3A/Semester%205/Pembelajaran%20Mesin/jobsheets/JS11_Parameter_Tunning/js11_03_tugas.ipynb#W4sZmlsZQ%3D%3D?line=19'>20</a> # Evaluasi dengan score
#      <a href='vscode-notebook-cell:/d%3A/Semester%205/Pembelajaran%20Mesin/jobsheets/JS11_Parameter_Tunning/js11_03_tugas.ipynb#W4sZmlsZQ%3D%3D?line=20'>21</a> score = grid.score(X,y)
#
# File c:\Users\62877\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2294, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2292     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2293 with self.builtin_trap:
# -> 2294     result = fn(*args, **kwargs)
#    2295 return result
#
# File c:\Users\62877\anaconda3\lib\site-packages\IPython\core\magics\execution.py:1162, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1160 for index in range(0, 10):
#    1161     number = 10 ** index
# -> 1162     time_number = timer.timeit(number)
#    1163     if time_number >= 0.2:
#    1164         break
#
# File c:\Users\62877\anaconda3\lib\site-packages\IPython\core\magics\execution.py:156, in Timer.timeit(self, number)
#     154 gc.disable()
#     155 try:
# --> 156     timing = self.inner(it, self.timer)
#     157 finally:
#     158     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# NameError: name 'random' is not defined
